# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriia-nekrasova/compling/blob/main/%D0%92%D1%82%D0%BE%D1%80%D0%BE%D0%B5_%D0%B4%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание

# %% [markdown]
# Представьте, что вы работаете аналитиком в проекте по разработке системы машинного перевода. Ваша команда создает систему машинного перевода на основе правил. Прежде чем ваши коллеги приступят к разработке системы, вам, как аналитику, нужно описать архитектуру будущей системы.
#
# Опишите структуру своей системы машинного перевода на основе правила в формате псевдокода, алгоритма или блок-схемы (на выбор). В процессе работы вам нужно будет ответить на следующие вопросы:
#
# + Какую языковую пару обрабатывает ваша система?
# + Какие виды анализа и предварительной обработки данных вы применяете?
# + Какие языковые правила вам нужно описать?
# + Как ваша система будет генерировать результат, т.е. перевод?
#
# Дополнительно попробуйте ответить на вопрос:
#
# + Какие библиотеки NLP вы будете использовать?

# %% [markdown]
# алгоритм
#
# Если брать систему машинного перевода английский -> немецкий, то языковой парой будут эти языки.
# Виды анализа и предварительной обработки данных: токенизация, лемматизация, частеречная разметка, синтаксический анализ
# Языковые правила: правила порядка слов в предложении (глагол на 2 месте, порядок слов по tekamolo, порядок слов в придаточном предложении), правила согласования рода, числа и падежа в немецком
# Генерирование результата: после синтаксической и лексической замены склеивает токены в строку, ищет лексические соответствия для каждого слова в немецком, первое слово пишет с большой буквы, выводит результат генерации
#
# 1. принимаем на вход текст пользователя на английском
# 2. составляем двуязычный лексикон для английского и немецкого
# 3. составление списка глаголов для морфологического анализа и списка существительных
# 4. токенизация исходного текста на английском
# 5. лемматизация
# 6. частеречная разметка
# 7. ввод правил синтаксической замены
# 8. лексический трансфер
#   8.1. ввод правил лексической замены
#   8.2 проверка сочетаемости слов
#   8.3 выбор подходящего значения
# 9. генерация слов
# 10. вывод на экран перевода текста на немецком
# ```
